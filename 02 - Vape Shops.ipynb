# %% [markdown]
# # Scraping Maryland Business Licenses with Selenium
#
# Maryland has a [great portal](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp) for searching business licenses, but the only problem is you have to check a box in order to get in.
#
# 1. Try to visit [the public search page](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp)
# 2. Get redirected to a "I agree to this" page. Click that you've read the disclaimer, click Enter the Site.
# 3. Click "Search License Records" down at the bottom of the page
# 4. You're now on the search page! From the "Jurisdiction" dropdown, select "Statewide"
# 5. In the "Trade Name" field, type "Vap%" to try to find vape shops
# 6. Click "Next" in the bottom right-hand corner to go to the next page
# 7. Click "Click for detail" to see the details for a specific business license.
#
# That's a lot of stuff! **Let's get to work.**

# %% [markdown]
# ## Import what you need

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

# %% [markdown]
# ## Preparation
#
# ### When you search for a business license, what URL should Selenium try to visit first?

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://jportal.mdcourts.gov/license/pbPublicSearch.jsp')

# %% [markdown]
# **It isn't going to work, though! It's going to redirect to that intro page.** You can use *Incognito mode* to go back through the "Check the box, etc" series of pages, or you can close and re-open Chrome.
#
# - Check the checkbox, then submit the form to accept their terms of service
#
# Selenium can submit forms by either
#
# - Selecting the form and using `.submit()`, or
# - Selecting the button and using `.click()`
#
# You only need to be able to get **one, not both.**
#
# - *TIP: if something doesn't have anything special about it, xpath might be your best bet*

# %%
check = driver.find_element_by_id('checkbox')
check.click()
button = driver.find_element_by_xpath('/html/body/table/tbody/tr[7]/td/form/div/input[2]')
button.click()

# %% [markdown]
# Now click the **Search License Records** link up top in the navigation to get to the search page.
#
# - *TIP: Honestly you could also just visit the URL directly now since you filled out that terms of service thing*

# %%
search = driver.find_element_by_xpath('/html/body/table[1]/tbody/tr[2]/td[2]/table/tbody/tr/td[3]/a/img')
search.click()

# %% [markdown]
# ### Perform your search
#
# Pick "Statewide" for the jurisdiction dropdown, and `VAP%` into the Trade Name field. The `%` is a wildcard.

# %%
select = Select(driver.find_element_by_name('slcJurisdiction'))
select.select_by_visible_text('Statewide')

# %%
text_input = driver.find_element_by_id('txtTradeName')
text_input.send_keys('VAP%')

# %% [markdown]
# And now, of course, **submit the form**.
#
# - *TIP: Since scrolling to buttons can be a pain, sometimes it's easier to select the form and use `.submit()` instead of `.click()`ing the button*

# %%
driver.find_element_by_id('txtTradeName').submit()

# %% [markdown]
# ## (Try to) scrape the results
#
# Let's start by just **printing this stuff**. We'll save it as a dataframe later on.
#
# For now, just scrape **each store's name**, then cry a little. Fact: this is an impossible and miserable page.

# %%
names = driver.find_elements_by_class_name('searchlistitem')
for name in names:
    print(name.text)
# Out:
# VAPE IT STORE II
# VAPE IT STORE I
# VAPEPAD THE
# VAPE FROG
# VAPE FROG

# %% [markdown]
# To avoid struggling with the search results page, we're going to use the **detail page** instead. Try to figure out how to select it and click it inside of your `for` loop.
#
# - *TIP: Instead of just looking for an `a` or an `img`, you might want to look for one of its parents first, then click. This might affect the way you print out the shop's name, too*
# - *TIP: Not all of them have links! You can wrap in try/except to skip it, or you can check to see if the shop's status is Pending.*

# %%
titles = driver.find_elements_by_class_name('searchfieldtitle')
for title in titles:
    try:
        title.find_element_by_tag_name('a').click()
        shop_name = driver.find_elements_by_class_name('tablecelltext')[1]
        print(shop_name.text.split('\n')[0])
        driver.find_element_by_partial_link_text('Return').click()
    except:
        print(title.find_element_by_class_name('searchlistitem').text)
# Out:
# VAPE IT STORE II
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-11-0f10cec18b65> in <module>()
#       3     try:
# ----> 4         title.find_element_by_tag_name('a').click()
#       5         shop_name = driver.find_elements_by_class_name('tablecelltext')[1]
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in find_element_by_tag_name(self, name)
#     304         """
# --> 305         return self.find_element(by=By.TAG_NAME, value=name)
#     306
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in find_element(self, by, value)
#     652         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 653                              {"using": by, "value": value})['value']
#     654
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     627         params['id'] = self._id
# --> 628         return self._parent.execute(command, params)
#     629
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     313         if response:
# --> 314             self.error_handler.check_response(response)
#     315             response['value'] = self._unwrap_value(
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.40.565386 (45a059dc425e08165f9a10324bd1380cc13ca363),platform=Mac OS X 10.13.5 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-11-0f10cec18b65> in <module>()
#       7         driver.find_element_by_partial_link_text('Return').click()
#       8     except:
# ----> 9         print(title.find_element_by_class_name('searchlistitem').text)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in find_element_by_class_name(self, name)
#     396             element = element.find_element_by_class_name('foo')
#     397         """
# --> 398         return self.find_element(by=By.CLASS_NAME, value=name)
#     399
#     400     def find_elements_by_class_name(self, name):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in find_element(self, by, value)
#     651
#     652         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 653                              {"using": by, "value": value})['value']
#     654
#     655     def find_elements(self, by=By.ID, value=None):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     626             params = {}
#     627         params['id'] = self._id
# --> 628         return self._parent.execute(command, params)
#     629
#     630     def find_element(self, by=By.ID, value=None):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     312         response = self.command_executor.execute(driver_command, params)
#     313         if response:
# --> 314             self.error_handler.check_response(response)
#     315             response['value'] = self._unwrap_value(
#     316                 response.get('value', None))
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.40.565386 (45a059dc425e08165f9a10324bd1380cc13ca363),platform=Mac OS X 10.13.5 x86_64)

# %% [markdown]
# Okay, now let's get to action. For each result, **click the link to the detail page** and print out the following information:
#
# - Mailing address
# - Location address
# - License information (you can keep it as one field)
# - Total amount paid
# - Issued by
# - If you're feeling crazy, get the licenses, too.
#
# If it doesn't have a detail page, just print out the name and that's all we need.
#
# - *TIP: When you're done getting the information, you probably want to click back to the search results*
# - *TIP: You might enjoy `find_element_by_partial_link_text` to do that*
# - *TIP: Licenses can be acquired by doing some really odd list slicing - think about where it starts and where it ends, relative to the beginning and end of everything.*
#
# > **IMPORTANT NOTE:** This is doomed. It's useful to do, but your current process is doomed. Once you get a `stale element reference` error move on to the next cell.

# %%
titles = driver.find_elements_by_class_name('searchfieldtitle')

for title in titles:
    try:
        title.find_element_by_tag_name('a').click()
        
        shop_name = driver.find_elements_by_class_name('tablecelltext')[1]
        print(shop_name.text.split('\n')[0])

        mail = driver.find_elements_by_class_name('tablecelltext')[0].find_element_by_tag_name('td')
        print(mail.text)

        location = driver.find_elements_by_class_name('tablecelltext')[1]
        print(shop_name.text)

        licence = driver.find_elements_by_class_name('tablecelltext')[0].find_elements_by_tag_name('td')[1]
        print(licence.text)

        amount = driver.find_elements_by_class_name('tablecelltext')[-3].find_elements_by_tag_name('td')[1]
        print(amount.text)

        issuer = driver.find_elements_by_class_name('tablecelltext')[-2].find_element_by_tag_name('td')
        print(issuer.text.split('\n')[0])
        
        driver.find_element_by_partial_link_text('Return').click()
        
    except:
        print(title.find_element_by_class_name('searchlistitem').text)
# Out:
# VAPE IT STORE II
# AMIN NARGIS
# 1104 PLANTERS PLACE
# SALISBURY, MD 21804
# VAPE IT STORE II
# 1015 S SALISBURY BLVD
# SALISBURY, MD 21801
# License Status: Issued
# License No.: 22375606
# Control No.: 22884439
# Date of Issue: 4/27/2018
# Months Paid: 12
# Exp. Date: 4/30/2019
# Subdivision: 22 Salisbury
# $ 41.00
# WICOMICO COUNTY, CLERK OF CIRCUIT COURT
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-12-2f43d91652ba> in <module>()
#       4     try:
# ----> 5         title.find_element_by_tag_name('a').click()
#       6
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in find_element_by_tag_name(self, name)
#     304         """
# --> 305         return self.find_element(by=By.TAG_NAME, value=name)
#     306
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in find_element(self, by, value)
#     652         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 653                              {"using": by, "value": value})['value']
#     654
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     627         params['id'] = self._id
# --> 628         return self._parent.execute(command, params)
#     629
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     313         if response:
# --> 314             self.error_handler.check_response(response)
#     315             response['value'] = self._unwrap_value(
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.40.565386 (45a059dc425e08165f9a10324bd1380cc13ca363),platform=Mac OS X 10.13.5 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-12-2f43d91652ba> in <module>()
#      26
#      27     except:
# ---> 28         print(title.find_element_by_class_name('searchlistitem').text)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in find_element_by_class_name(self, name)
#     396             element = element.find_element_by_class_name('foo')
#     397         """
# --> 398         return self.find_element(by=By.CLASS_NAME, value=name)
#     399
#     400     def find_elements_by_class_name(self, name):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in find_element(self, by, value)
#     651
#     652         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 653                              {"using": by, "value": value})['value']
#     654
#     655     def find_elements(self, by=By.ID, value=None):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     626             params = {}
#     627         params['id'] = self._id
# --> 628         return self._parent.execute(command, params)
#     629
#     630     def find_element(self, by=By.ID, value=None):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     312         response = self.command_executor.execute(driver_command, params)
#     313         if response:
# --> 314             self.error_handler.check_response(response)
#     315             response['value'] = self._unwrap_value(
#     316                 response.get('value', None))
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.40.565386 (45a059dc425e08165f9a10324bd1380cc13ca363),platform=Mac OS X 10.13.5 x86_64)

# %% [markdown]
# ### Stale message reference
#
# Once you navigate away from a page, and you go back to it, you can't use the variables from the first time you were on the page. So, we got a list of results when we first visited, clicked to the details page, clicked back, and now our original list is "stale."
#
# This is sad.
#
# Let's try this again: loop through the results and create a dataframe with `name` and `url` columns. And yes, some of them won't have URLs.

# %%
vape_list = []
titles = driver.find_elements_by_class_name('searchfieldtitle')

for title in titles:
    vape_dic = {}
    try:
        name = title.find_elements_by_tag_name('td')[1]
        vape_dic['Name'] = name.text
        url = title.find_element_by_tag_name('a').get_attribute('href')
        vape_dic['URL'] = url        
    except:
        vape_dic['URL'] = ''
    vape_list.append(vape_dic)

import pandas as pd
df = pd.DataFrame(vape_list)
df
# Out:
#                Name                                                URL
# 0  VAPE IT STORE II  https://jportal.mdcourts.gov/license/pbLicense...
# 1   VAPE IT STORE I  https://jportal.mdcourts.gov/license/pbLicense...
# 2       VAPEPAD THE  https://jportal.mdcourts.gov/license/pbLicense...
# 3         VAPE FROG
# 4         VAPE FROG

# %% [markdown]
# ### Getting all of the results
#
# After you've looped through the results on one page, we're going to want to go to the next page! Add a line to make it click the 'Next' button down at the bottom
#
# - *Tip: `find_element_by_partial_link_text` will be your friend*
# - *Tip: You might need to do the scrolling thing to get it onto the screen (and by that I mean, you WILL need to, so you should)*
#
# Confirm that it moves to the next page (it doesn't need to scrape anything yet)

# %%
button = driver.find_element_by_link_text('Next »')
driver.execute_script("arguments[0].scrollIntoView(true)", button)
button.click()

# %% [markdown]
# ### Wrapping with `while`
#
# > Go back to the first page of results before you try to run this
#
# You have a bunch of scraping code. It clicks the next button, then it stops. But you'd like it to go back up to the top! You can make that happen with a special `while` loop.
#
# ```python
# while True:
#     # Scrape your stuff
#     # Click next button
# ```
#
# This will go on FOREVER AND EVER until there is an error (when it can't find the Next button on the last page of results, you'll get an error).
#
# - *Tip: Print out "Scraping a new page" every time you visit a new page, just to check that it's working*

# %%
while True:
    try:
        print('Scraping a new page')
        button = driver.find_element_by_link_text('Next »')
        driver.execute_script("arguments[0].scrollIntoView(true)", button)
        button.click()
    except:
        break
# Out:
# Scraping a new page
# Scraping a new page
# Scraping a new page
# Scraping a new page
# Scraping a new page
# Scraping a new page

# %% [markdown]
# ### Making it perfect
#
# > Go back to the first page of results before you try to run this
#
# Wrap all of your code in a `try`/`except` so that it doesn't finish with an error and you'll be good to go.
#
# **Confirm your list has all of the vape shops in it.** If not, check where you are creating your empty list (`[]`) - if you do it in the wrong spot, it will overwrite your list every time you visit a page.

# %%
vape_list = []

while True:
    titles = driver.find_elements_by_class_name('searchfieldtitle')
    for title in titles:
        vape_dic = {}
        try:
            name = title.find_elements_by_tag_name('td')[1]
            vape_dic['Name'] = name.text
            url = title.find_element_by_tag_name('a').get_attribute('href')
            vape_dic['URL'] = url        
        except:
            vape_dic['URL'] = ''
        vape_list.append(vape_dic)
    try:    
        button = driver.find_element_by_link_text('Next »')
        driver.execute_script("arguments[0].scrollIntoView(true)", button)
        button.click()
    except:
        break
        
print(vape_list)
# Out:
# [{'Name': 'VAPE IT STORE II', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=gnyBHTQ8GIg%3D'}, {'Name': 'VAPE IT STORE I', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=T2TZR2VEhr0%3D'}, {'Name': 'VAPEPAD THE', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=VSQ3xHdhms4%3D'}, {'Name': 'VAPE FROG', 'URL': ''}, {'Name': 'VAPE FROG', 'URL': ''}, {'Name': 'VAPE LOFT THE', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=o72cBz7w0rM%3D'}, {'Name': 'VAPE N CIGAR', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=AvgayV6k4oo%3D'}, {'Name': 'VAPE DOJO', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=XqL00plcNyk%3D'}, {'Name': 'VAPE HAVEN', 'URL': ''}, {'Name': 'VAPORS LOUNGE', 'URL': ''}, {'Name': 'VAPORFI SOUTHSIDE', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=9hXnAl%2FbwlI%3D'}, {'Name': 'VAPE DO JO', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=qe1SUvDLg14%3D'}, {'Name': 'VAPERTETMD', 'URL': ''}, {'Name': 'VAPERTEKMD', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=mtAdy9aofbE%3D'}, {'Name': 'VAPORIOT', 'URL': ''}, {'Name': 'VAPE PLUS', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ZilboI057J8%3D'}, {'Name': 'VAPE SOCIAL', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=kcFNvYi8Fj0%3D'}, {'Name': 'VAPE JUNGLE', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=DvEdcCIuUyw%3D'}, {'Name': 'VAPE TIME', 'URL': ''}, {'Name': 'VAPEBAR EXPESS', 'URL': ''}, {'Name': 'VAPEWERKS', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=r%2BRUe1dK7Qo%3D'}, {'Name': 'VAPIST MD', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Fp9XYNuiQkY%3D'}, {'Name': 'VAPOR 99', 'URL': ''}, {'Name': 'VAPOR ALLEY', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=l72iLDVvGG0%3D'}, {'Name': 'VAPOR EMPORIUM', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=tLJpqtB7Uy8%3D'}, {'Name': 'VAPOR VILLA', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=4hdfgcxG42I%3D'}, {'Name': 'VAPOR VILLA', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=FdQXpo1VAQY%3D'}, {'Name': 'VAPORS LOUNGE', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=TPmmvUojzAw%3D'}, {'Name': 'VAPE DOJO', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=GWQHIdmlwsY%3D'}, {'Name': 'VAPE DOJO', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=w4f5v2%2BFdfY%3D'}, {'Name': 'VAPE DOJO', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=nwBacyWQlc8%3D'}, {'Name': 'VAPE DOJO', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Meu2%2FWI%2FECs%3D'}, {'Name': 'VAPEZ YARDHOUSE', 'URL': ''}, {'Name': 'VAPERS RING', 'URL': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=YWXRbg2sYY0%3D'}]

# %% [markdown]
# ### Save this data as a csv
#
# The filename should be `vape-shops-basic.csv`.

# %%
import pandas as pd
df = pd.DataFrame(vape_list)
df
# Out:
#                  Name                                                URL
# 0    VAPE IT STORE II  https://jportal.mdcourts.gov/license/pbLicense...
# 1     VAPE IT STORE I  https://jportal.mdcourts.gov/license/pbLicense...
# 2         VAPEPAD THE  https://jportal.mdcourts.gov/license/pbLicense...
# 3           VAPE FROG
# 4           VAPE FROG
# 5       VAPE LOFT THE  https://jportal.mdcourts.gov/license/pbLicense...
# 6        VAPE N CIGAR  https://jportal.mdcourts.gov/license/pbLicense...
# 7           VAPE DOJO  https://jportal.mdcourts.gov/license/pbLicense...
# 8          VAPE HAVEN
# 9       VAPORS LOUNGE
# 10  VAPORFI SOUTHSIDE  https://jportal.mdcourts.gov/license/pbLicense...
# 11         VAPE DO JO  https://jportal.mdcourts.gov/license/pbLicense...
# 12         VAPERTETMD
# 13         VAPERTEKMD  https://jportal.mdcourts.gov/license/pbLicense...
# 14           VAPORIOT
# 15          VAPE PLUS  https://jportal.mdcourts.gov/license/pbLicense...
# 16        VAPE SOCIAL  https://jportal.mdcourts.gov/license/pbLicense...
# 17        VAPE JUNGLE  https://jportal.mdcourts.gov/license/pbLicense...
# 18          VAPE TIME
# 19     VAPEBAR EXPESS
# 20          VAPEWERKS  https://jportal.mdcourts.gov/license/pbLicense...
# 21          VAPIST MD  https://jportal.mdcourts.gov/license/pbLicense...
# 22           VAPOR 99
# 23        VAPOR ALLEY  https://jportal.mdcourts.gov/license/pbLicense...
# 24     VAPOR EMPORIUM  https://jportal.mdcourts.gov/license/pbLicense...
# 25        VAPOR VILLA  https://jportal.mdcourts.gov/license/pbLicense...
# 26        VAPOR VILLA  https://jportal.mdcourts.gov/license/pbLicense...
# 27      VAPORS LOUNGE  https://jportal.mdcourts.gov/license/pbLicense...
# 28          VAPE DOJO  https://jportal.mdcourts.gov/license/pbLicense...
# 29          VAPE DOJO  https://jportal.mdcourts.gov/license/pbLicense...
# 30          VAPE DOJO  https://jportal.mdcourts.gov/license/pbLicense...
# 31          VAPE DOJO  https://jportal.mdcourts.gov/license/pbLicense...
# 32    VAPEZ YARDHOUSE
# 33        VAPERS RING  https://jportal.mdcourts.gov/license/pbLicense...

# %%
df.to_csv('vape-shops-basic.csv', index=False)

# %% [markdown]
# # Okay, let's scrape!
#
# All right, get the actual data!
#
# ### Look at the URL of your first row
#
# - *TIP: Remember `pd.set_option('display.max_colwidth', -1)` will let you see alllll of your strings*

# %%
df = pd.read_csv('vape-shops-basic.csv')
pd.set_option('display.max_colwidth', -1)
df
# Out:
#                  Name  \
# 0   VAPE IT STORE II
# 1   VAPE IT STORE I
# 2   VAPEPAD THE
# 3   VAPE FROG
# 4   VAPE FROG
# 5   VAPE LOFT THE
# 6   VAPE N CIGAR
# 7   VAPE DOJO
# 8   VAPE HAVEN
# 9   VAPORS LOUNGE
# 10  VAPORFI SOUTHSIDE
# 11  VAPE DO JO
# 12  VAPERTETMD
# 13  VAPERTEKMD
# 14  VAPORIOT
# 15  VAPE PLUS
# 16  VAPE SOCIAL
# 17  VAPE JUNGLE
# 18  VAPE TIME
# 19  VAPEBAR EXPESS
# 20  VAPEWERKS
# 21  VAPIST MD
# 22  VAPOR 99
# 23  VAPOR ALLEY
# 24  VAPOR EMPORIUM
# 25  VAPOR VILLA
# 26  VAPOR VILLA
# 27  VAPORS LOUNGE
# 28  VAPE DOJO
# 29  VAPE DOJO
# 30  VAPE DOJO
# 31  VAPE DOJO
# 32  VAPEZ YARDHOUSE
# 33  VAPERS RING
#
#                                                                                 URL
# 0   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=gnyBHTQ8GIg%3D
# 1   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=T2TZR2VEhr0%3D
# 2   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=VSQ3xHdhms4%3D
# 3   NaN
# 4   NaN
# 5   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=o72cBz7w0rM%3D
# 6   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=AvgayV6k4oo%3D
# 7   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=XqL00plcNyk%3D
# 8   NaN
# 9   NaN
# 10  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=9hXnAl%2FbwlI%3D
# 11  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=qe1SUvDLg14%3D
# 12  NaN
# 13  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=mtAdy9aofbE%3D
# 14  NaN
# 15  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ZilboI057J8%3D
# 16  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=kcFNvYi8Fj0%3D
# 17  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=DvEdcCIuUyw%3D
# 18  NaN
# 19  NaN
# 20  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=r%2BRUe1dK7Qo%3D
# 21  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Fp9XYNuiQkY%3D
# 22  NaN
# 23  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=l72iLDVvGG0%3D
# 24  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=tLJpqtB7Uy8%3D
# 25  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=4hdfgcxG42I%3D
# 26  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=FdQXpo1VAQY%3D
# 27  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=TPmmvUojzAw%3D
# 28  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=GWQHIdmlwsY%3D
# 29  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=w4f5v2%2BFdfY%3D
# 30  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=nwBacyWQlc8%3D
# 31  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Meu2%2FWI%2FECs%3D
# 32  NaN
# 33  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=YWXRbg2sYY0%3D

# %% [markdown]
# ### Use Selenium to visit that page

# %%
urls = df['URL']
for url in urls:
    try:
        driver.get(url)
    except:
        pass

# %% [markdown]
# ### Now, just like you did before, grab the additional data
#
# You should probably save it into a dictionary! Don't try to put it into the dataframe yet, though. You want:
#
# - Mailing address
# - Location address
# - License information (you can keep it as one field)
# - Total amount paid
# - Issued by
# - If you're feeling crazy, get the licenses, too.
#
# .
#
# - *TIP: Licenses can be acquired by doing some really odd list slicing - think about where it starts and where it ends, relative to the beginning and end of everything.*
# - *TIP: If you've gotten addicted to xpath, total amount paid and issued by might not work with it when doing other shops. You'll want to test it!*

# %%
additional_data = {}

mail = driver.find_elements_by_class_name('tablecelltext')[0].find_element_by_tag_name('td')
additional_data['Mailing address'] = mail.text

location = driver.find_elements_by_class_name('tablecelltext')[1]
additional_data['Location address'] = location.text

licence = driver.find_elements_by_class_name('tablecelltext')[0].find_elements_by_tag_name('td')[1]
additional_data['License information'] = licence.text

amount = driver.find_elements_by_class_name('tablecelltext')[-3].find_elements_by_tag_name('td')[1]
additional_data['Total amount paid'] = amount.text

issuer = driver.find_elements_by_class_name('tablecelltext')[-2].find_element_by_tag_name('td')
additional_data['Issued by'] = issuer.text.split('\n')[0]

additional_data
# Out:
# {'Mailing address': 'YEAGER ONE INC\n545 HIGGINS DR\nODENTON, MD 21113',
#  'Location address': 'VAPERS RING\n545 BENFIELD RD\nSEVERNA PARK, MD 21146',
#  'License information': 'License Status: Issued\nLicense No.: 02311125\nControl No.: 02111865\nDate of Issue: 5/22/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 02 Anne Arundel County',
#  'Total amount paid': '$ 116.00',
#  'Issued by': 'ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT'}

# %% [markdown]
# ### Move all of this into one cell
#
# It should visit the URL, then grab the data and put it into a dictionary.

# %%
additional_list = []

urls = df['URL']
for url in urls:
    additional_data = {}
    try:
        driver.get(url)
        
        mail = driver.find_elements_by_class_name('tablecelltext')[0].find_element_by_tag_name('td')
        additional_data['Mailing address'] = mail.text

        location = driver.find_elements_by_class_name('tablecelltext')[1]
        additional_data['Location address'] = location.text

        licence = driver.find_elements_by_class_name('tablecelltext')[0].find_elements_by_tag_name('td')[1]
        additional_data['License information'] = licence.text

        amount = driver.find_elements_by_class_name('tablecelltext')[-3].find_elements_by_tag_name('td')[1]
        additional_data['Total amount paid'] = amount.text

        issuer = driver.find_elements_by_class_name('tablecelltext')[-2].find_element_by_tag_name('td')
        additional_data['Issued by'] = issuer.text.split('\n')[0]
        
        additional_list.append(additional_data)

    except:
        pass

print(additional_list)
# Out:
# [{'Mailing address': 'AMIN NARGIS\n1104 PLANTERS PLACE\nSALISBURY, MD 21804', 'Location address': 'VAPE IT STORE II\n1015 S SALISBURY BLVD\nSALISBURY, MD 21801', 'License information': 'License Status: Issued\nLicense No.: 22375606\nControl No.: 22884439\nDate of Issue: 4/27/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 22 Salisbury', 'Total amount paid': '$ 41.00', 'Issued by': 'WICOMICO COUNTY, CLERK OF CIRCUIT COURT'}, {'Mailing address': 'AMIN NARGIS\n1104 PLANTERS PLACE\nSALISBURY, MD 21804', 'Location address': 'VAPE IT STORE I\n1724 N SALISBURY BLVD UNIT 2\nSALISBURY, MD 21801', 'License information': 'License Status: Issued\nLicense No.: 22375605\nControl No.: 22591855\nDate of Issue: 4/27/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 22 Salisbury', 'Total amount paid': '$ 24.00', 'Issued by': 'WICOMICO COUNTY, CLERK OF CIRCUIT COURT'}, {'Mailing address': 'ANJ DISTRIBUTIONS LLC\n2504 ORCHARD KNOLL WAY\nODENTON, MD 21113', 'Location address': 'VAPEPAD THE\n2299 JOHNS HOPKINS ROAD\nGAMBRILLS, MD 21054', 'License information': 'License Status: Issued\nLicense No.: 02304705\nControl No.: 02685930\nDate of Issue: 4/05/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 02 Anne Arundel County', 'Total amount paid': '$ 94.00', 'Issued by': 'ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT'}, {'Mailing address': 'DISBROW II EMERSON HARRINGTON', 'Location address': 'VAPE LOFT THE\n185 MITCHELLS CHANCE RD\nEDGEWATER, MD 21037', 'License information': 'License Status: Issued\nLicense No.: 02310799\nControl No.: 02686069\nDate of Issue: 4/03/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 02 Anne Arundel County', 'Total amount paid': '$ 154.00', 'Issued by': 'ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT'}, {'Mailing address': 'DISCOUNT TOBACCO ESSEX LLC', 'Location address': 'VAPE N CIGAR\n7104 MINSTREL UNIT #7\nCOLUMBIA, MD 21045', 'License information': 'License Status: Issued\nLicense No.: 13343011\nControl No.: 13856368\nDate of Issue: 4/30/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 13 Howard County', 'Total amount paid': '$ 84.00', 'Issued by': 'WAYNE A. ROBEY, CLERK OF CIRCUIT COURT'}, {'Mailing address': 'FAIRGROUND VILLAGE LLC', 'Location address': 'VAPE DOJO\n330 ONE FORTY VILLAGE ROAD\nUNIT 15\nWESTMINSTER, MD 21157', 'License information': 'License Status: Issued\nLicense No.: 06327188\nControl No.: 06946760\nDate of Issue: 4/05/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 06 Westminster', 'Total amount paid': '$ 179.00', 'Issued by': 'DONALD B. SEALING II, CLERK OF CIRCUIT COURT'}, {'Mailing address': 'JENS VAPOR LLC', 'Location address': 'VAPORFI SOUTHSIDE\n853 EAST FORT AVE\nBALTIMORE, MD 21230', 'License information': 'License Status: Issued\nLicense No.: 30390631\nControl No.: 30190160\nDate of Issue: 4/20/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 30 Baltimore City', 'Total amount paid': '$ 189.00', 'Issued by': 'MARILYN BENTLEY, CLERK CIRCUIT COURT'}, {'Mailing address': 'MONROE LLC', 'Location address': 'VAPE DO JO\n2021 LIBERTY ROAD\nSYKESVILLE, MD 21784', 'License information': 'License Status: Issued\nLicense No.: 06328812\nControl No.: 06328812\nDate of Issue: 5/03/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 06 Sykesville', 'Total amount paid': '$ 154.00', 'Issued by': 'DONALD B. SEALING II, CLERK OF CIRCUIT COURT'}, {'Mailing address': 'SHIN JENNY YOUNG\n6800 GUEST CALL SUITE 425\nELKRIDGE, MD 21075', 'Location address': 'VAPERTEKMD\n6325 WASHINGTON BLVD STE N\nELKRIDGE, MD 21075', 'License information': 'License Status: Issued\nLicense No.: 13342043\nControl No.: 13961721\nDate of Issue: 5/07/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 13 Howard County', 'Total amount paid': '$ 34.00', 'Issued by': 'WAYNE A. ROBEY, CLERK OF CIRCUIT COURT'}, {'Mailing address': 'TRUE ENTERPRISE INC\n5967 OXBRIDGE DRIVE\nSALISBURY, MD 21801', 'Location address': 'VAPE PLUS\n519 LINDEN AVENUE UNIT 6\nPOCOMOKE CITY, MD 218 ...

# %% [markdown]
# ### Change it into a function
#
# You'll want to have this function accept a `row`, and send back a `pd.Series`. You can just use `pd.Series(your_dictionary)` (but it better have a better name than `your_dictionary`!).
#
# - *TIP: Make sure you `return` something!*
# - *TIP: Make sure you change everything to reflect the row's url, not the URL you typed in*

# %%
def get_vape_info(row):
    try:
        driver.get(row['URL'])
        mail = driver.find_elements_by_class_name('tablecelltext')[0].find_element_by_tag_name('td').text
        location = driver.find_elements_by_class_name('tablecelltext')[1].text
        license = driver.find_elements_by_class_name('tablecelltext')[0].find_elements_by_tag_name('td')[1].text
        amount = driver.find_elements_by_class_name('tablecelltext')[-3].find_elements_by_tag_name('td')[1].text
        issuer = driver.find_elements_by_class_name('tablecelltext')[-2].find_element_by_tag_name('td').text.split('\n')[0]

        return pd.Series({
            'Mailing address': mail,
            'Location address': location,
            'License information': license,
            'Total amount paid': amount,
            'Issued by': issuer
        })
    
    except:
        
        return pd.Series({
            'Mailing address': '',
            'Location address': '',
            'License information': '',
            'Total amount paid': '',
            'Issued by': ''
        })

# %% [markdown]
# ### Use your dataframe and `.apply` to pull all of the data from the vape shops
#
# Once you know it's working, use the whole
#
# - *TIP: Try using it with `.head(3)` first*
# - *TIP: You'll want to use `.apply` with your new function*
# - *TIP: Issued By and Total Paid are goign to give you problems if you tried to use xpath! Try checking the classes and think about find_elementSSSSS and working backwards instead of forwards.*
# - *TIP: You might need a `try`/`except`*
# - *TIP: Make sure you're using `axis=1`*
# - *TIP: Use `.join` the big thing with all of the `dfs` - make sure you name them right!*

# %%
vape_df = df.apply(get_vape_info, axis=1).join(df)
vape_df
# Out:
#                                                                          Mailing address  \
# 0   AMIN NARGIS\n1104 PLANTERS PLACE\nSALISBURY, MD 21804
# 1   AMIN NARGIS\n1104 PLANTERS PLACE\nSALISBURY, MD 21804
# 2   ANJ DISTRIBUTIONS LLC\n2504 ORCHARD KNOLL WAY\nODENTON, MD 21113
# 3
# 4
# 5   DISBROW II EMERSON HARRINGTON
# 6   DISCOUNT TOBACCO ESSEX LLC
# 7   FAIRGROUND VILLAGE LLC
# 8
# 9
# 10  JENS VAPOR LLC
# 11  MONROE LLC
# 12
# 13  SHIN JENNY YOUNG\n6800 GUEST CALL SUITE 425\nELKRIDGE, MD 21075
# 14
# 15  TRUE ENTERPRISE INC\n5967 OXBRIDGE DRIVE\nSALISBURY, MD 21801
# 16  VAPE SOCIAL LLC
# 17  VAPE JUNGLE LLC\n63 E CHESAPEAKE BEACH ROAD\nOWINGS, MD 20736
# 18
# 19
# 20  VAPEWERKS LLC\n155 WILLOW AVENUE\nKEYSER, WV 26726
# 21  VAPIST MD LLC\n2119 CREEKS EDGE LANE\nWALDORF, MD 20601
# 22
# 23  VAPOR ALLEY LLC\n8117 OCEAN GATEWAY UNIT #4\nEASTON, MARYLAND 21601
# 24  VAPOR EMPORIUM MD LLC
# 25  VAPOR VILLA CORP
# 26  VAPOR VILLA CORP
# 27  VAPORS LOUNGE LLC
# 28  WALKER TRADING CO INC\n11600 CROSSROADS CIRCLE\nSUITE E\nMIDDLE RIVER, MD 21220
# 29  WALKER TRADING COMPANY INC\n11600 CROSSROADS CIRCLE\nSUITE E\nMIDDLE RIVER, MD 21220
# 30  WALKER TRADING COMPANY INC
# 31  WALKER TRADING COMPANY INC\n11600 CROSSROADS CIRCLE\nSUITE E\nMIDDLE RIVER, MD 21220
# 32
# 33  YEAGER ONE INC\n545 HIGGINS DR\nODENTON, MD 21113
#
#                                                           Location address  \
# 0   VAPE IT STORE II\n1015 S SALISBURY BLVD\nSALISBURY, MD 21801
# 1   VAPE IT STORE I\n1724 N SALISBURY BLVD UNIT 2\nSALISBURY, MD 21801
# 2   VAPEPAD THE\n2299 JOHNS HOPKINS ROAD\nGAMBRILLS, MD 21054
# 3
# 4
# 5   VAPE LOFT THE\n185 MITCHELLS CHANCE RD\nEDGEWATER, MD 21037
# 6   VAPE N CIGAR\n7104 MINSTREL UNIT #7\nCOLUMBIA, MD 21045
# 7   VAPE DOJO\n330 ONE FORTY VILLAGE ROAD\nUNIT 15\nWESTMINSTER, MD 21157
# 8
# 9
# 10  VAPORFI SOUTHSIDE\n853 EAST FORT AVE\nBALTIMORE, MD 21230
# 11  VAPE DO JO\n2021 LIBERTY ROAD\nSYKESVILLE, MD 21784
# 12
# 13  VAPERTEKMD\n6325 WASHINGTON BLVD STE N\nELKRIDGE, MD 21075
# 14
# 15  VAPE PLUS\n519 LINDEN AVENUE UNIT 6\nPOCOMOKE CITY, MD 21851
# 16  VAPE SOCIAL\n16521 S FREDERICK AVE\nGAITHERSBURG, MD 20877
# 17  VAPE JUNGLE\n2070 CRAIN HIGHWAY UNIT F\nWALDORF, MD 20601
# 18
# 19
# 20  VAPEWERKS\n16115 MCMULLEN HWY SW\nUNIT 7\nCUMBERLAND, MD 21502
# 21  VAPIST MD\n6321 OLD BRANCH AVE\nCAMP SPRINGS, MD 20748
# 22
# 23  VAPOR ALLEY\n8117 OCEAN GATEWAY UNIT #4\nEASTON, MD 21601
# 24  VAPOR EMPORIUM\n11717 OLD NATIONAL PIKE\nUNIT 3B\nNEW MARKET, MD 21774
# 25  VAPOR VILLA\n1913 LANSDOWNE ROAD\nSUITE E\nBALTIMORE, MD 21227
# 26  VAPOR VILLA\n730 FREDERICK ROAD\nSUITE 202\nCATONSVILLE, MD 21228
# 27  VAPORS LOUNGE\n28943 THREE NOTCH ROAD\nMECHANICSVILLE, MD 20659
# 28  VAPE DOJO\n138 N BOND STREET\nBEL AIR, MD 21014
# 29  VAPE DOJO\n331 GAMBRILLS ROAD\nGAMBRILLS, MD 21054
# 30  VAPE DOJO\n11600 CROSSROAD CIR STE E\nBALTIMORE, MD 21220
# 31  VAPE DOJO\n3570 SAINT JOHNS LANE, SUITE 109\nELLICOTT CITY, MD 21042
# 32
# 33  VAPERS RING\n545 BENFIELD RD\nSEVERNA PARK, MD 21146
#
#                                                                                                                                                               License information  \
# 0   License Status: Issued\nLicense No.: 22375606\nControl No.: 22884439\nDate of Issue: 4/27/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 22 Salisbury
# 1   License Status: Issued\nLicense No.: 22375605\nControl No.: 22591855\nDate of Issue: 4/27/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 22 Salisbury
# 2   License Status: Issued\nLicense No.: 02304705\nControl No.: 02685930\nDate of Issue: 4/05/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 02 Anne Arundel County
# 3
# 4
# 5   License Status: Issued\nLicense No.: 02310799\nControl No.: 02686069\nDate of Issue: 4/03/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 02 Anne Arundel County
# 6   License Status: Issued\nLicense No.: 13343011\nControl No.: 13856368\nDate of Issue: 4/30/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 13 Howard County
# 7   License Status: Issued\nLicense No.: 06327188\nControl No.: 06946760\nDate of Issue: 4/05/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 06 Westminster
# 8
# 9
# 10  License Status: Issued\nLicense No.: 30390631\nControl No.: 30190160\nDate of Issue: 4/20/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 30 Baltimore City
# 11  License Status: Issued\nLicense No.: 06328812\nControl No.: 06328812\nDate of Issue: 5/03/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 06 Sykesville
# 12
# 13  License Status: Issued\nLicense No.: 13342043\nControl No.: 13961721\nDate of Issue: 5/07/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 13 Howard County
# 14
# 15  License Status: Issued\nLicense No.: 23380005\nControl No.: 23990202\nDate of Issue: 5/31/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 23 Pocomoke
# 16  License Status: Issued\nLicense No.: 15356789\nControl No.: 15728050\nDate of Issue: 4/12/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 15 Gaithersburg
# 17  License Status: Issued\nLicense No.: 08332318\nControl No.: 08844059\nDate of Issue: 4/09/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 08 Charles County
# 18
# 19
# 20  License Status: Issued\nLicense No.: 01302079\nControl No.: 01102169\nDate of Issue: 6/07/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 01 Allegany County
# 21  License Status: Issued\nLicense No.: 16366948\nControl No.: 16166805\nDate of Issue: 5/05/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 16 Prince George's County
# 22
# 23  License Status: Issued\nLicense No.: 20372618\nControl No.: 20739879\nDate of Issue: 4/24/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 20 Easton
# 24  License Status: Issued\nLicense No.: 10336513\nControl No.: 10954003\nDate of Issue: 5/04/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 10 Frederick County
# 25  License Status: Issued\nLicense No.: 03322784\nControl No.: 03696574\nDate of Issue: 4/26/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 03 Baltimore County
# 26  License Status: Issued\nLicense No.: 03322785\nControl No.: 03696931\nDate of Issue: 4/26/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 03 Baltimore County
# 27  License Status: Issued\nLicense No.: 18369505\nControl No.: 18877819\nDate of Issue: 4/17/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 18 St. Mary's County
# 28  License Status: Issued\nLicense No.: 12341351\nControl No.: 12958340\nDate of Issue: 5/29/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 12 Bel Air
# 29  License Status: Issued\nLicense No.: 02310917\nControl No.: 02111914\nDate of Issue: 6/01/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 02 Anne Arundel County
# 30  License Status: Issued\nLicense No.: 03322944\nControl No.: 03837488\nDate of Issue: 5/30/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 03 Baltimore County
# 31  License Status: Issued\nLicense No.: 13345355\nControl No.: 13563224\nDate of Issue: 5/23/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 13 Howard County
# 32
# 33  License Status: Issued\nLicense No.: 02311125\nControl No.: 02111865\nDate of Issue: 5/22/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 02 Anne Arundel County
#
#    Total amount paid                                      Issued by  \
# 0   $ 41.00           WICOMICO COUNTY, CLERK OF CIRCUIT COURT
# 1   $ 24.00           WICOMICO COUNTY, CLERK OF CIRCUIT COURT
# 2   $ 94.00           ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT
# 3
# 4
# 5   $ 154.00          ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT
# 6   $ 84.00           WAYNE A. ROBEY, CLERK OF CIRCUIT COURT
# 7   $ 179.00          DONALD B. SEALING II, CLERK OF CIRCUIT COURT
# 8
# 9
# 10  $ 189.00          MARILYN BENTLEY, CLERK CIRCUIT COURT
# 11  $ 154.00          DONALD B. SEALING II, CLERK OF CIRCUIT COURT
# 12
# 13  $ 34.00           WAYNE A. ROBEY, CLERK OF CIRCUIT COURT
# 14
# 15  $ 37.00           SUSAN R. BRANIECKI, CLERK OF CIRCUIT COURT
# 16  $ 32.00           BARBARA H. MEIKLEJOHN, CLERK OF CIRCUIT COURT
# 17  $ 110.00          SHARON L. HANCOCK, CLERK OF CIRCUIT COURT
# 18
# 19
# 20  $ 132.50          DAWNE D. LINDSEY, CLERK OF CIRCUIT COURT
# 21  $ 69.00           SYDNEY J. HARRISON, CLERK OF CIRCUIT COURT
# 22
# 23  $ 229.00          MARY ANN SHORTALL, CLERK OF CIRCUIT COURT
# 24  $ 229.00          SANDRA DALTON, CLERK OF CIRCUIT COURT
# 25  $ 123.00          JULIE L. ENSOR, CLERK OF CIRCUIT COURT
# 26  $ 123.00          JULIE L. ENSOR, CLERK OF CIRCUIT COURT
# 27  $ 94.00           TRACY CANTRELL, ACTING CLERK OF CIRCUIT COURT
# 28  $ 68.50           JAMES J. REILLY, CLERK OF CIRCUIT COURT
# 29  $ 118.50          ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT
# 30  $ 414.33          JULIE L. ENSOR, CLERK OF CIRCUIT COURT
# 31  $ 78.50           WAYNE A. ROBEY, CLERK OF CIRCUIT COURT
# 32
# 33  $ 116.00          ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT
#
#                  Name  \
# 0   VAPE IT STORE II
# 1   VAPE IT STORE I
# 2   VAPEPAD THE
# 3   VAPE FROG
# 4   VAPE FROG
# 5   VAPE LOFT THE
# 6   VAPE N CIGAR
# 7   VAPE DOJO
# 8   VAPE HAVEN
# 9   VAPORS LOUNGE
# 10  VAPORFI SOUTHSIDE
# 11  VAPE DO JO
# 12  VAPERTETMD
# 13  VAPERTEKMD
# 14  VAPORIOT
# 15  VAPE PLUS
# 16  VAPE SOCIAL
# 17  VAPE JUNGLE
# 18  VAPE TIME
# 19  VAPEBAR EXPESS
# 20  VAPEWERKS
# 21  VAPIST MD
# 22  VAPOR 99
# 23  VAPOR ALLEY
# 24  VAPOR EMPORIUM
# 25  VAPOR VILLA
# 26  VAPOR VILLA
# 27  VAPORS LOUNGE
# 28  VAPE DOJO
# 29  VAPE DOJO
# 30  VAPE DOJO
# 31  VAPE DOJO
# 32  VAPEZ YARDHOUSE
# 33  VAPERS RING
#
#                                                                                 URL
# 0   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=gnyBHTQ8GIg%3D
# 1   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=T2TZR2VEhr0%3D
# 2   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=VSQ3xHdhms4%3D
# 3   NaN
# 4   NaN
# 5   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=o72cBz7w0rM%3D
# 6   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=AvgayV6k4oo%3D
# 7   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=XqL00plcNyk%3D
# 8   NaN
# 9   NaN
# 10  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=9hXnAl%2FbwlI%3D
# 11  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=qe1SUvDLg14%3D
# 12  NaN
# 13  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=mtAdy9aofbE%3D
# 14  NaN
# 15  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ZilboI057J8%3D
# 16  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=kcFNvYi8Fj0%3D
# 17  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=DvEdcCIuUyw%3D
# 18  NaN
# 19  NaN
# 20  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=r%2BRUe1dK7Qo%3D
# 21  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Fp9XYNuiQkY%3D
# 22  NaN
# 23  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=l72iLDVvGG0%3D
# 24  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=tLJpqtB7Uy8%3D
# 25  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=4hdfgcxG42I%3D
# 26  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=FdQXpo1VAQY%3D
# 27  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=TPmmvUojzAw%3D
# 28  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=GWQHIdmlwsY%3D
# 29  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=w4f5v2%2BFdfY%3D
# 30  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=nwBacyWQlc8%3D
# 31  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Meu2%2FWI%2FECs%3D
# 32  NaN
# 33  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=YWXRbg2sYY0%3D

# %% [markdown]
# ## Save as `vape-total.csv`
#
# Make sure you don't save the index! Open it up in a text editor or Excel to make sure it's correct.

# %%
vape_df.to_csv('vape-total.csv', index=False)

# %%
df = pd.read_csv('vape-total.csv')
df
# Out:
#                                                                          Mailing address  \
# 0   AMIN NARGIS\n1104 PLANTERS PLACE\nSALISBURY, MD 21804
# 1   AMIN NARGIS\n1104 PLANTERS PLACE\nSALISBURY, MD 21804
# 2   ANJ DISTRIBUTIONS LLC\n2504 ORCHARD KNOLL WAY\nODENTON, MD 21113
# 3   NaN
# 4   NaN
# 5   DISBROW II EMERSON HARRINGTON
# 6   DISCOUNT TOBACCO ESSEX LLC
# 7   FAIRGROUND VILLAGE LLC
# 8   NaN
# 9   NaN
# 10  JENS VAPOR LLC
# 11  MONROE LLC
# 12  NaN
# 13  SHIN JENNY YOUNG\n6800 GUEST CALL SUITE 425\nELKRIDGE, MD 21075
# 14  NaN
# 15  TRUE ENTERPRISE INC\n5967 OXBRIDGE DRIVE\nSALISBURY, MD 21801
# 16  VAPE SOCIAL LLC
# 17  VAPE JUNGLE LLC\n63 E CHESAPEAKE BEACH ROAD\nOWINGS, MD 20736
# 18  NaN
# 19  NaN
# 20  VAPEWERKS LLC\n155 WILLOW AVENUE\nKEYSER, WV 26726
# 21  VAPIST MD LLC\n2119 CREEKS EDGE LANE\nWALDORF, MD 20601
# 22  NaN
# 23  VAPOR ALLEY LLC\n8117 OCEAN GATEWAY UNIT #4\nEASTON, MARYLAND 21601
# 24  VAPOR EMPORIUM MD LLC
# 25  VAPOR VILLA CORP
# 26  VAPOR VILLA CORP
# 27  VAPORS LOUNGE LLC
# 28  WALKER TRADING CO INC\n11600 CROSSROADS CIRCLE\nSUITE E\nMIDDLE RIVER, MD 21220
# 29  WALKER TRADING COMPANY INC\n11600 CROSSROADS CIRCLE\nSUITE E\nMIDDLE RIVER, MD 21220
# 30  WALKER TRADING COMPANY INC
# 31  WALKER TRADING COMPANY INC\n11600 CROSSROADS CIRCLE\nSUITE E\nMIDDLE RIVER, MD 21220
# 32  NaN
# 33  YEAGER ONE INC\n545 HIGGINS DR\nODENTON, MD 21113
#
#                                                           Location address  \
# 0   VAPE IT STORE II\n1015 S SALISBURY BLVD\nSALISBURY, MD 21801
# 1   VAPE IT STORE I\n1724 N SALISBURY BLVD UNIT 2\nSALISBURY, MD 21801
# 2   VAPEPAD THE\n2299 JOHNS HOPKINS ROAD\nGAMBRILLS, MD 21054
# 3   NaN
# 4   NaN
# 5   VAPE LOFT THE\n185 MITCHELLS CHANCE RD\nEDGEWATER, MD 21037
# 6   VAPE N CIGAR\n7104 MINSTREL UNIT #7\nCOLUMBIA, MD 21045
# 7   VAPE DOJO\n330 ONE FORTY VILLAGE ROAD\nUNIT 15\nWESTMINSTER, MD 21157
# 8   NaN
# 9   NaN
# 10  VAPORFI SOUTHSIDE\n853 EAST FORT AVE\nBALTIMORE, MD 21230
# 11  VAPE DO JO\n2021 LIBERTY ROAD\nSYKESVILLE, MD 21784
# 12  NaN
# 13  VAPERTEKMD\n6325 WASHINGTON BLVD STE N\nELKRIDGE, MD 21075
# 14  NaN
# 15  VAPE PLUS\n519 LINDEN AVENUE UNIT 6\nPOCOMOKE CITY, MD 21851
# 16  VAPE SOCIAL\n16521 S FREDERICK AVE\nGAITHERSBURG, MD 20877
# 17  VAPE JUNGLE\n2070 CRAIN HIGHWAY UNIT F\nWALDORF, MD 20601
# 18  NaN
# 19  NaN
# 20  VAPEWERKS\n16115 MCMULLEN HWY SW\nUNIT 7\nCUMBERLAND, MD 21502
# 21  VAPIST MD\n6321 OLD BRANCH AVE\nCAMP SPRINGS, MD 20748
# 22  NaN
# 23  VAPOR ALLEY\n8117 OCEAN GATEWAY UNIT #4\nEASTON, MD 21601
# 24  VAPOR EMPORIUM\n11717 OLD NATIONAL PIKE\nUNIT 3B\nNEW MARKET, MD 21774
# 25  VAPOR VILLA\n1913 LANSDOWNE ROAD\nSUITE E\nBALTIMORE, MD 21227
# 26  VAPOR VILLA\n730 FREDERICK ROAD\nSUITE 202\nCATONSVILLE, MD 21228
# 27  VAPORS LOUNGE\n28943 THREE NOTCH ROAD\nMECHANICSVILLE, MD 20659
# 28  VAPE DOJO\n138 N BOND STREET\nBEL AIR, MD 21014
# 29  VAPE DOJO\n331 GAMBRILLS ROAD\nGAMBRILLS, MD 21054
# 30  VAPE DOJO\n11600 CROSSROAD CIR STE E\nBALTIMORE, MD 21220
# 31  VAPE DOJO\n3570 SAINT JOHNS LANE, SUITE 109\nELLICOTT CITY, MD 21042
# 32  NaN
# 33  VAPERS RING\n545 BENFIELD RD\nSEVERNA PARK, MD 21146
#
#                                                                                                                                                               License information  \
# 0   License Status: Issued\nLicense No.: 22375606\nControl No.: 22884439\nDate of Issue: 4/27/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 22 Salisbury
# 1   License Status: Issued\nLicense No.: 22375605\nControl No.: 22591855\nDate of Issue: 4/27/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 22 Salisbury
# 2   License Status: Issued\nLicense No.: 02304705\nControl No.: 02685930\nDate of Issue: 4/05/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 02 Anne Arundel County
# 3   NaN
# 4   NaN
# 5   License Status: Issued\nLicense No.: 02310799\nControl No.: 02686069\nDate of Issue: 4/03/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 02 Anne Arundel County
# 6   License Status: Issued\nLicense No.: 13343011\nControl No.: 13856368\nDate of Issue: 4/30/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 13 Howard County
# 7   License Status: Issued\nLicense No.: 06327188\nControl No.: 06946760\nDate of Issue: 4/05/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 06 Westminster
# 8   NaN
# 9   NaN
# 10  License Status: Issued\nLicense No.: 30390631\nControl No.: 30190160\nDate of Issue: 4/20/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 30 Baltimore City
# 11  License Status: Issued\nLicense No.: 06328812\nControl No.: 06328812\nDate of Issue: 5/03/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 06 Sykesville
# 12  NaN
# 13  License Status: Issued\nLicense No.: 13342043\nControl No.: 13961721\nDate of Issue: 5/07/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 13 Howard County
# 14  NaN
# 15  License Status: Issued\nLicense No.: 23380005\nControl No.: 23990202\nDate of Issue: 5/31/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 23 Pocomoke
# 16  License Status: Issued\nLicense No.: 15356789\nControl No.: 15728050\nDate of Issue: 4/12/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 15 Gaithersburg
# 17  License Status: Issued\nLicense No.: 08332318\nControl No.: 08844059\nDate of Issue: 4/09/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 08 Charles County
# 18  NaN
# 19  NaN
# 20  License Status: Issued\nLicense No.: 01302079\nControl No.: 01102169\nDate of Issue: 6/07/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 01 Allegany County
# 21  License Status: Issued\nLicense No.: 16366948\nControl No.: 16166805\nDate of Issue: 5/05/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 16 Prince George's County
# 22  NaN
# 23  License Status: Issued\nLicense No.: 20372618\nControl No.: 20739879\nDate of Issue: 4/24/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 20 Easton
# 24  License Status: Issued\nLicense No.: 10336513\nControl No.: 10954003\nDate of Issue: 5/04/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 10 Frederick County
# 25  License Status: Issued\nLicense No.: 03322784\nControl No.: 03696574\nDate of Issue: 4/26/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 03 Baltimore County
# 26  License Status: Issued\nLicense No.: 03322785\nControl No.: 03696931\nDate of Issue: 4/26/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 03 Baltimore County
# 27  License Status: Issued\nLicense No.: 18369505\nControl No.: 18877819\nDate of Issue: 4/17/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 18 St. Mary's County
# 28  License Status: Issued\nLicense No.: 12341351\nControl No.: 12958340\nDate of Issue: 5/29/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 12 Bel Air
# 29  License Status: Issued\nLicense No.: 02310917\nControl No.: 02111914\nDate of Issue: 6/01/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 02 Anne Arundel County
# 30  License Status: Issued\nLicense No.: 03322944\nControl No.: 03837488\nDate of Issue: 5/30/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 03 Baltimore County
# 31  License Status: Issued\nLicense No.: 13345355\nControl No.: 13563224\nDate of Issue: 5/23/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 13 Howard County
# 32  NaN
# 33  License Status: Issued\nLicense No.: 02311125\nControl No.: 02111865\nDate of Issue: 5/22/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 02 Anne Arundel County
#
#    Total amount paid                                      Issued by  \
# 0   $ 41.00           WICOMICO COUNTY, CLERK OF CIRCUIT COURT
# 1   $ 24.00           WICOMICO COUNTY, CLERK OF CIRCUIT COURT
# 2   $ 94.00           ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT
# 3   NaN               NaN
# 4   NaN               NaN
# 5   $ 154.00          ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT
# 6   $ 84.00           WAYNE A. ROBEY, CLERK OF CIRCUIT COURT
# 7   $ 179.00          DONALD B. SEALING II, CLERK OF CIRCUIT COURT
# 8   NaN               NaN
# 9   NaN               NaN
# 10  $ 189.00          MARILYN BENTLEY, CLERK CIRCUIT COURT
# 11  $ 154.00          DONALD B. SEALING II, CLERK OF CIRCUIT COURT
# 12  NaN               NaN
# 13  $ 34.00           WAYNE A. ROBEY, CLERK OF CIRCUIT COURT
# 14  NaN               NaN
# 15  $ 37.00           SUSAN R. BRANIECKI, CLERK OF CIRCUIT COURT
# 16  $ 32.00           BARBARA H. MEIKLEJOHN, CLERK OF CIRCUIT COURT
# 17  $ 110.00          SHARON L. HANCOCK, CLERK OF CIRCUIT COURT
# 18  NaN               NaN
# 19  NaN               NaN
# 20  $ 132.50          DAWNE D. LINDSEY, CLERK OF CIRCUIT COURT
# 21  $ 69.00           SYDNEY J. HARRISON, CLERK OF CIRCUIT COURT
# 22  NaN               NaN
# 23  $ 229.00          MARY ANN SHORTALL, CLERK OF CIRCUIT COURT
# 24  $ 229.00          SANDRA DALTON, CLERK OF CIRCUIT COURT
# 25  $ 123.00          JULIE L. ENSOR, CLERK OF CIRCUIT COURT
# 26  $ 123.00          JULIE L. ENSOR, CLERK OF CIRCUIT COURT
# 27  $ 94.00           TRACY CANTRELL, ACTING CLERK OF CIRCUIT COURT
# 28  $ 68.50           JAMES J. REILLY, CLERK OF CIRCUIT COURT
# 29  $ 118.50          ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT
# 30  $ 414.33          JULIE L. ENSOR, CLERK OF CIRCUIT COURT
# 31  $ 78.50           WAYNE A. ROBEY, CLERK OF CIRCUIT COURT
# 32  NaN               NaN
# 33  $ 116.00          ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT
#
#                  Name  \
# 0   VAPE IT STORE II
# 1   VAPE IT STORE I
# 2   VAPEPAD THE
# 3   VAPE FROG
# 4   VAPE FROG
# 5   VAPE LOFT THE
# 6   VAPE N CIGAR
# 7   VAPE DOJO
# 8   VAPE HAVEN
# 9   VAPORS LOUNGE
# 10  VAPORFI SOUTHSIDE
# 11  VAPE DO JO
# 12  VAPERTETMD
# 13  VAPERTEKMD
# 14  VAPORIOT
# 15  VAPE PLUS
# 16  VAPE SOCIAL
# 17  VAPE JUNGLE
# 18  VAPE TIME
# 19  VAPEBAR EXPESS
# 20  VAPEWERKS
# 21  VAPIST MD
# 22  VAPOR 99
# 23  VAPOR ALLEY
# 24  VAPOR EMPORIUM
# 25  VAPOR VILLA
# 26  VAPOR VILLA
# 27  VAPORS LOUNGE
# 28  VAPE DOJO
# 29  VAPE DOJO
# 30  VAPE DOJO
# 31  VAPE DOJO
# 32  VAPEZ YARDHOUSE
# 33  VAPERS RING
#
#                                                                                 URL
# 0   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=gnyBHTQ8GIg%3D
# 1   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=T2TZR2VEhr0%3D
# 2   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=VSQ3xHdhms4%3D
# 3   NaN
# 4   NaN
# 5   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=o72cBz7w0rM%3D
# 6   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=AvgayV6k4oo%3D
# 7   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=XqL00plcNyk%3D
# 8   NaN
# 9   NaN
# 10  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=9hXnAl%2FbwlI%3D
# 11  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=qe1SUvDLg14%3D
# 12  NaN
# 13  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=mtAdy9aofbE%3D
# 14  NaN
# 15  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ZilboI057J8%3D
# 16  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=kcFNvYi8Fj0%3D
# 17  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=DvEdcCIuUyw%3D
# 18  NaN
# 19  NaN
# 20  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=r%2BRUe1dK7Qo%3D
# 21  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Fp9XYNuiQkY%3D
# 22  NaN
# 23  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=l72iLDVvGG0%3D
# 24  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=tLJpqtB7Uy8%3D
# 25  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=4hdfgcxG42I%3D
# 26  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=FdQXpo1VAQY%3D
# 27  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=TPmmvUojzAw%3D
# 28  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=GWQHIdmlwsY%3D
# 29  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=w4f5v2%2BFdfY%3D
# 30  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=nwBacyWQlc8%3D
# 31  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Meu2%2FWI%2FECs%3D
# 32  NaN
# 33  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=YWXRbg2sYY0%3D
